# %%
import gradio as gr

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (5.38.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.11.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (1.11.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (2.2.5)
# Requirement already satisfied: orjson~=3.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (3.11.1)
# Requirement already satisfied: packaging in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.47.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio-client==1.11.0->gradio) (2025.7.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from gradio-client==1.11.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.1.0)
# Requirement already satisfied: colorama in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: filelock in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.5.0)

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipywidgets) (9.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: colorama in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: wcwidth in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import ollama
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import ollama
#
# ModuleNotFoundError: No module named 'ollama'

# %%
# !pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from ollama) (2.11.7)
# Requirement already satisfied: anyio in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpx>=0.27->ollama) (4.7.0)
# Requirement already satisfied: certifi in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpx>=0.27->ollama) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpx>=0.27->ollama) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pydantic>=2.9->ollama) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sangr\anaconda3\envs\python-starter\lib\site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)
# Downloading ollama-0.5.1-py3-none-any.whl (13 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.5.1

# %%
import ollama

# %%
# function to perform EDA and generate visulization
def eda_analysis(file_path):
    df= pd.read_csv(file_path)

# %%
#fill missing values with median for numeric columns
for col in df.select_dtypes(include=['number'].columns):
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 #fill missing values with median for numeric columns
# ----> 2 for col in df.select_dtypes(include=['number'].columns):
#       3     df[col].fillna(df[col].median(), inplace=True)
#
# NameError: name 'df' is not defined

# %%
import gradio as gr

# %%
def greet(name, intensity):
    return "hello," + "!" * int(intensity)

# %%
demo = gr.interface(
    fn=greet,
    inputs =["text", "slider"],
    output= ["text"],)
demo.lunch()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 demo = gr.interface(
#       2     fn=greet,
#       3     inputs =["text", "slider"],
#       4     output= ["text"],)
#       5 demo.lunch()
#
# TypeError: 'module' object is not callable

# %%
import gradio as gr

def greet(name, intensity):
    return "Hello, " + name + "!" * int(intensity)

demo = gr.Interface(
    fn=greet,
    inputs=["text", "slider"],
    outputs=["text"]
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Created dataset file at: .gradio\flagged\dataset1.csv
